# %%
import pandas as pd
import seaborn as sns

df = pd.read_csv("out777.csv", names=["density", "incubation_time", "iteration", 
                                   "seed", "winner", "steps"])

df = df[df["winner"] == "human"]
a = df[["winner", "density", "incubation_time"]].groupby(["density", "incubation_time", "winner"])

# %%
b = a.size().unstack(fill_value=0)
b = b.reset_index()

# %%
b.set_index("density")
# sns.heatmap(b, annot=True)
# Out:
# winner   incubation_time  human
# density
# 0.05                   0     37
# 0.05                   3     31
# 0.05                   6     29
# 0.05                   9     31
# 0.05                  12     28
# 0.05                  15     17
# 0.15                   0     38
# 0.15                   3     38
# 0.15                   6     29
# 0.15                   9     31
# 0.15                  12     26
# 0.15                  15      7
# 0.25                   0     41
# 0.25                   3     40
# 0.25                   6     26
# 0.25                   9     26
# 0.25                  12     30
# 0.25                  15     14
# 0.35                   0     47
# 0.35                   3     47
# 0.35                   6     40
# 0.35                   9     32
# 0.35                  12     34
# 0.35                  15     15
# 0.45                   0     50
# 0.45                   3     48
# 0.45                   6     45
# 0.45                   9     43
# ...

# %%
df = pd.read_csv("out.csv", names=["density", "grouping", "iteration", 
                                   "seed", "winner", "steps"])

grouping = df[df["grouping"] == True]
no_grouping = df[df["grouping"] == False]

print(len(grouping[grouping["winner"] == "human"]))
print(len(grouping[grouping["winner"] == "zombies"]))

print(len(no_grouping[no_grouping["winner"] == "human"]))
print(len(no_grouping[no_grouping["winner"] == "zombies"]))
# Out:
# 42
# 8
# 35
# 15

# %%
df = pd.read_csv("group_output2.csv", names=["density", "grouping", "iteration", 
                                   "seed", "winner", "steps"])

grouping = df[df["grouping"] == True]
no_grouping = df[df["grouping"] == False]

print(len(grouping[grouping["winner"] == "human"]))
print(len(grouping[grouping["winner"] == "zombies"]))

print(len(no_grouping[no_grouping["winner"] == "human"]))
print(len(no_grouping[no_grouping["winner"] == "zombies"]))
# Out:
# 40
# 10
# 30
# 20
